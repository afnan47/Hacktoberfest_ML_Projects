# %%
import pandas as pd
from google.colab import files
import io
data=files.upload()
# Out:
#      <input type="file" id="files-07253fc0-bae0-432e-a7f9-975987030a83" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-07253fc0-bae0-432e-a7f9-975987030a83">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving titanic3.csv to titanic3.csv

# %%
df=pd.read_csv(io.StringIO(data['titanic3.csv'].decode('utf-8')))

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
inputs=df.drop(['survived','name','sibsp','parch','ticket','cabin','embarked','body','home.dest','boat'],axis='columns')

# %%
inputs
# Out:
#       pclass     sex      age      fare
# 0        1.0  female  29.0000  211.3375
# 1        1.0    male   0.9167  151.5500
# 2        1.0  female   2.0000  151.5500
# 3        1.0    male  30.0000  151.5500
# 4        1.0  female  25.0000  151.5500
# ...      ...     ...      ...       ...
# 1305     3.0  female      NaN   14.4542
# 1306     3.0    male  26.5000    7.2250
# 1307     3.0    male  27.0000    7.2250
# 1308     3.0    male  29.0000    7.8750
# 1309     NaN     NaN      NaN       NaN
#
# [1310 rows x 4 columns]

# %% [markdown]
# define the target which is survived

# %%
target=df.survived

# %%
from sklearn.preprocessing import LabelEncoder
gender=LabelEncoder()

# %%
inputs['sex_n']=gender.fit_transform(inputs['sex'])

# %%
inputs.age[:20]
# Out:
# 0     29.000000
# 1      0.916700
# 2      2.000000
# 3     30.000000
# 4     25.000000
# 5     48.000000
# 6     63.000000
# 7     39.000000
# 8     53.000000
# 9     71.000000
# 10    47.000000
# 11    18.000000
# 12    24.000000
# 13    26.000000
# 14    80.000000
# 15    29.881135
# 16    24.000000
# 17    50.000000
# 18    32.000000
# 19    36.000000
# Name: age, dtype: float64

# %%
inputs.age=inputs.age.fillna(inputs.age.mean())

# %%
inputs.dropna()
# Out:
#       pclass     sex        age      fare  sex_n
# 0        1.0  female  29.000000  211.3375      0
# 1        1.0    male   0.916700  151.5500      1
# 2        1.0  female   2.000000  151.5500      0
# 3        1.0    male  30.000000  151.5500      1
# 4        1.0  female  25.000000  151.5500      0
# ...      ...     ...        ...       ...    ...
# 1304     3.0  female  14.500000   14.4542      0
# 1305     3.0  female  29.881135   14.4542      0
# 1306     3.0    male  26.500000    7.2250      1
# 1307     3.0    male  27.000000    7.2250      1
# 1308     3.0    male  29.000000    7.8750      1
#
# [1308 rows x 5 columns]

# %%
inputs
# Out:
#       pclass     sex        age      fare  sex_n
# 0        1.0  female  29.000000  211.3375      0
# 1        1.0    male   0.916700  151.5500      1
# 2        1.0  female   2.000000  151.5500      0
# 3        1.0    male  30.000000  151.5500      1
# 4        1.0  female  25.000000  151.5500      0
# ...      ...     ...        ...       ...    ...
# 1305     3.0  female  29.881135   14.4542      0
# 1306     3.0    male  26.500000    7.2250      1
# 1307     3.0    male  27.000000    7.2250      1
# 1308     3.0    male  29.000000    7.8750      1
# 1309     NaN     NaN  29.881135       NaN      2
#
# [1310 rows x 5 columns]

# %%
input_n=inputs.drop(['sex'],axis='columns')

# %%
input_n
# Out:
#       pclass        age      fare  sex_n
# 0        1.0  29.000000  211.3375      0
# 1        1.0   0.916700  151.5500      1
# 2        1.0   2.000000  151.5500      0
# 3        1.0  30.000000  151.5500      1
# 4        1.0  25.000000  151.5500      0
# ...      ...        ...       ...    ...
# 1305     3.0  29.881135   14.4542      0
# 1306     3.0  26.500000    7.2250      1
# 1307     3.0  27.000000    7.2250      1
# 1308     3.0  29.000000    7.8750      1
# 1309     NaN  29.881135       NaN      2
#
# [1310 rows x 4 columns]

# %%
input_n.dropna()
# Out:
#       pclass        age      fare  sex_n
# 0        1.0  29.000000  211.3375      0
# 1        1.0   0.916700  151.5500      1
# 2        1.0   2.000000  151.5500      0
# 3        1.0  30.000000  151.5500      1
# 4        1.0  25.000000  151.5500      0
# ...      ...        ...       ...    ...
# 1304     3.0  14.500000   14.4542      0
# 1305     3.0  29.881135   14.4542      0
# 1306     3.0  26.500000    7.2250      1
# 1307     3.0  27.000000    7.2250      1
# 1308     3.0  29.000000    7.8750      1
#
# [1308 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(input_n,target,test_size=0.2)

# %%
len(X_train)
# Out:
# 1048

# %%
len(X_test)
# Out:
# 262

# %%
from sklearn import tree
model=tree.DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-151-b7a8c64777c1> in <module>()
# ----> 1 model.fit(X_train,y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     940             sample_weight=sample_weight,
#     941             check_input=check_input,
# --> 942             X_idx_sorted=X_idx_sorted,
#     943         )
#     944         return self
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     164             check_y_params = dict(ensure_2d=False, dtype=None)
#     165             X, y = self._validate_data(
# --> 166                 X, y, validate_separately=(check_X_params, check_y_params)
#     167             )
#     168             if issparse(X):
#
# ...

# %%
model.score(X_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-145-d3b3987fd8a5> in <module>()
# ----> 1 model.score(X_test,y_test)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     649         from .metrics import accuracy_score
#     650
# --> 651         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     652
#     653     def _more_tags(self):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in predict(self, X, check_input)
#     465         """
#     466         check_is_fitted(self)
# --> 467         X = self._validate_X_predict(X, check_input)
#     468         proba = self.tree_.predict(X)
#     469         n_samples = X.shape[0]
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in _validate_X_predict(self, X, check_input)
# ...
